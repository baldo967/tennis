# %%
import numpy as np
from scipy.special import binom
import matplotlib.pyplot as plt

# %%
giocatori= ("Federer, Nadal")
punti= [0,15,30,40,"AD"]
game= [0,1,2,3,4,5,6,7]
sets= [0,1,2]

punti_giocati=7
punti_fatti=np.random.randint(0,2,(punti_giocati))
Punti_nadal=punti_fatti.sum(axis=-1)
Punti_federer=punti_giocati-Punti_nadal
def punteggioNadal(Punti_nadal,):
  if (Punti_nadal<3):
    Punti_nadal=Punti_nadal*15
  elif (Punti_nadal>3):
    Punti_nadal="game"
    print ("Nadal Win")
  else:
    Punti_nadal=40
  return Punti_nadal
  
def punteggioFederer(Punti_federer,):
  if (Punti_federer<3):
     Punti_federer=Punti_federer*15
  elif (Punti_federer>3):
    Punti_federer="game"
    print("Federer Win")
  else:
    Punti_federer=40
  return Punti_federer
PunteggioA= punteggioNadal(Punti_nadal)
PunteggioB= punteggioFederer(Punti_federer)
tabellone=[PunteggioA,PunteggioB]
tabellone
# Out:
# Nadal Win
# ['game', 40]

# %%
giocatori= ("Federer, Nadal")
punti= [0,15,30,40,"AD"]
game= [0,1,2,3,4,5,6,7]
sets= [0,1,2]
punti_giocati=5
punti_fatti=np.random.randint(0,2,(punti_giocati))
Punti_nadal=punti_fatti.sum(axis=-1)
Punti_federer=punti_giocati-Punti_nadal
def punteggioNadal(Punti_nadal,):
  if (Punti_nadal<3):
    
  Punti_nadal=Punti_nadal*15
  else:
    Punti_nadal=40
  return Punti_nadal
  
def punteggioFederer(Punti_federer,):
  if (Punti_federer<3):
  Punti_federer=Punti_federer*15
  else:
    Punti_federer=40
  return Punti_federer
PunteggioA= punteggioNadal(Punti_nadal)
PunteggioB= punteggioFederer(Punti_federer)
tabellone=[PunteggioA,PunteggioB]
tabellone
# Out:
#   File "<ipython-input-28-326ac95820fc>", line 11
#     Punti_nadal=Punti_nadal*15
#               ^
# IndentationError: expected an indented block
